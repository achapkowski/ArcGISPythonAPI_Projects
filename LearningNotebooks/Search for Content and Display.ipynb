# %%
from arcgis.gis import GIS
gis = GIS("https://capone.maps.arcgis.com", "", "")

# %%
search_result = gis.content.search(query="title:Optidots", item_type="Feature Layer")
search_result
# Out:
# [<Item title:"LosAngeles_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>,
#  <Item title:"Chicago_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>,
#  <Item title:"Miami_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>,
#  <Item title:"Atlanta_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>,
#  <Item title:"Boston_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>,
#  <Item title:"Chicago_Optidots_CUR" type:Feature Service owner:alberto.nieto.cof>,
#  <Item title:"Raleigh_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>,
#  <Item title:"SanFrancisco_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>,
#  <Item title:"Minneapolis_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>,
#  <Item title:"Philadelphia_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>]

# %%
broad_search_result = gis.content.search(query="", item_type="Feature Layer", max_items=1000)
broad_search_result
# Out:
# [<Item title:"PreferredThinRetailers_National" type:Feature Service owner:alberto.nieto.cof>,
#  <Item title:"Competitors" type:Feature Service owner:alberto.nieto.cof>,
#  <Item title:"CoffeeShops" type:Feature Service owner:JSchule>,
#  <Item title:"Denver Location Tracking" type:Feature Service owner:johnmdye>,
#  <Item title:"DenverFieldCollection - Remove by Thanksgiving" type:Feature Service owner:johnmdye>,
#  <Item title:"Chicago_LocationTracking" type:Feature Service owner:alberto.nieto.cof>,
#  <Item title:"Demand" type:Feature Service owner:alberto.nieto.cof>,
#  <Item title:"LosAngeles_LocationTracking" type:Feature Service owner:alberto.nieto.cof>,
#  <Item title:"CRA_LowModerate_OPS" type:Feature Service owner:alberto.nieto.cof>,
#  <Item title:"MP_AnnotatedAreas" type:Feature Service owner:alberto.nieto.cof>,
#  <Item title:"Worker_Density" type:Feature Service owner:alberto.nieto.cof>,
#  <Item title:"MP_Notes_OPS" type:Feature Service owner:alberto.nieto.cof>,
# ...

# %%
len(broad_search_result)
# Out:
# 370

# %%
from IPython.display import display
for item in search_result:
    display(item)
# Out:
# <Item title:"LosAngeles_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>
# <Item title:"Chicago_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>
# <Item title:"Miami_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>
# <Item title:"Atlanta_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>
# <Item title:"Boston_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>
# <Item title:"Chicago_Optidots_CUR" type:Feature Service owner:alberto.nieto.cof>
# <Item title:"Raleigh_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>
# <Item title:"SanFrancisco_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>
# <Item title:"Minneapolis_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>
# <Item title:"Philadelphia_Optidots_OPS" type:Feature Service owner:alberto.nieto.cof>
